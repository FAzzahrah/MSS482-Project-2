# %% [markdown]
# ---
# <h1 style="text-align: center;">
#
# School of Mathematical Sciences,
# Universiti Sains Malaysia
#
# MSS482: Graphing Technology in Mathematics and Science
#
# Semester I: Academic Session 2023/2024
#
# </h1>
#
# >R.U.Gobithaasan (2023). School of Mathematical Sciences, Universiti Sains Malaysia.\
# [Official Website](https://math.usm.my/academic-profile/705-gobithaasan-rudrusamy)
# ---

# %% [markdown]
# ## Project 2: 7.5%
# - CLO1 – 7.5%,
# - CLO2 – 10%,
# - CLO3 – 2.5%
#
# ### Due: 22nd January 2023 (5.00 PM)
#
# 1. This is a group work (2 to 5 students per group).
# 2. Write a complete report using the given Jupyter Notebook to demonstrate the following tasks:
#
#     - [CLO1, C3] Choose a suitable dataset from various sources, such as books, the internet, or any relevant references, and use Python to build a regression model. (7.5M)
#
#     -  [CLO2, P4] Conduct suitable statistical techniques to develop the regression model. (5M)
#
#
#     - [CLO2, P4] Construct and execute the most suitable Python codes to develop the regression model effectively. (5M)
#
#
#     - [CLO3, A3] Adopt suitable references for this project. (2.5M)
#
#
# For guidelines, you may refer to the following examples/problems:
#
# •	An Introduction to Python Environment and Datasets
# •	Distribution Statistics & Data Visualization
# •	Analyzing More Than One Variable Data
# •	Scatterplots, Linear & Multiple Regression
#
# **COPYING CASES WILL BE PENALIZED BETWEEN GROUPS; 0 MARKS WILL BE GIVEN TO BOTH PARTIES.**

# %% [markdown]
# ## Fill up the following declaration details (agreed and signed by team leader):
# **We certify that this report is our own work, based on our personal study and/or research. We also certify that this report has not previously been submitted for assessment in any other unit, and that we have not copied in part or whole or otherwise plagiarized the work of other students and/or persons.**
#
# | NO. | NAME | MATRIC NUMBER | ROLE|
# |---|---|---| ---|
# |1|Ainon Najihah binti Azahari|153354|Methodology|
# |2|Fatin Amirah binti Mohd Fahmi|151722|Discussion, Conclusion|
# |3|Siti Fatimah Azzahrah Binti Azhar | 153632 | About DataSet, Methodology |
# |4|Ainul Farhah Binti Abd Azis| 150918 | Methodology, References|
#
#
# - Name (Group Leader): Ainon Najihah binti Azahari
# - Matrix Number: 153354
# - Date: 26 January 2024
#
#   GitHub link: https://github.com/FAzzahrah/MSS482-Project-3
# ---

# %% [markdown]
# <h3 style="text-align: center;">
#
# Assessment Rubric for Project 2: (please refer to the pdf file).
#
# </h3>
#
# |Attribute |Assessment Criteria |Weightage (%) | Marks |
# |:---:|:---:|:---:|:---:|
# |Cognitive Domain I (CO1,P01,C3)| (a) Title and details of the problem. |2.5||
# |Cognitive Domain II (CO1,P01,C3)| (b) The details of the dataset, dependent and independent variable(s). |5.0||
# | Psychomotor Domain I (CO2,PO2,P4) |(c) Construction and execution the packages/methods/functions of Python codes for developing the regression model. |4.0| |
# | Psychomotor Domain II (CO2,PO2,P4) |(d) Display the results and discussion with detailed visualization. |4.0| |
# | Psychomotor Domain III (CO2,PO2,P4) |(e) Conclusion of the project which may lead to an informed decision by administrators. |2.0| |
# | Communication Skills (CO3,PO4,A3)|(f) References |2.5| |
# | |Total/Score|20 | ||

# %% [markdown]
# ---
#
# # 1. PROJECT TITLE: RELATION BETWEEN LOAN AMOUNT WITH LOAN DEFAULT AND COMBINED INCOME
#
# ---
#
# (a) Title and details of the problem.

# %% [markdown]
# Title: Relation Between Loan Amount With Loan Default and Combined Income

# %% [markdown]
# Problem Statement: This study aims to explore the relations between Loan Amount with Loan Default and Combined Income utilizing linear regression model. The fact that applying loan required many details of applicant such as gender, number of dependents, credit history, income and even coapplicant income. The study is expected to provide actionable insights to support decision-making processes related to loan amount approved based on loan default and combined income.

# %% [markdown]
# ---
#
# # 2. ABOUT DATASET
#
# ---
# (b) The details of the dataset, dependent and independent variable(s).

# %% [markdown]
# The applicants dataset obtained from private data source from Kaggle. It contains various information about loan applicants:

# %% [markdown]
# | **Variable** | **Description** |
# |:-----:|:-----:|
# |Loan_ID |Unique Loan ID|
# |Gender |Male/Female |
# |Married |Applicant married (Y/N) |
# |Dependents |Number of dependents |
# |Education |Applicant Education (Graduate/ Under Graduate) |
# |Self_Employed |Self employed (Y/N) |
# |ApplicantIncome |Applicant income |
# |CoapplicantIncome |Coapplicant income |
# |CombinedIncome | Total income of applicant and coapplicant |
# |LoanAmount |Loan Amount in thousand|
# |Loan_Amount_Term |Term of loan in months |
# |Credit_History |Credit history meets guidelines |
# |Property_Area |Urban/ Semi Urban/ Rural |
# |Loan_Status |Loan Approved (Y/N) |
# |Loan_Default |Fails to repay (Y/N) |

# %% [markdown]
# This study focuses on the relations between the **loan amount (dependent variable)** and two **independent variables: combined income and loan default**. The dataset includes various other variables, but for the purpose of this linear regression model only loan amount, loan default and combined income are considered.
#
# Loan default and combined income play crucial rule in measure loan amount. Combined income provides a measure of the borrower's overall financial capacity by considering the income of both the applicant and the coapplicant. By including combined income as an independent varaible in the model, it allows for an assessment of the applicant's ability to afford a higher loan amount. Higher combined income suggest a greater capacity to handle larger loan amounts.
#
# Meanwhile, loan default can provide insights into the applicant's creditwothiness and past repayment behavior. By including loan default in this analysis, the model can assess the relations between loan default and loan amount. This can help evaluate the risk associated with higher loan amounts, as applicants with a history of default may be more likely to default on larger loans.

# %% [markdown]
# ---
#
# # 3 METHODOLOGY & RESULTS
#
# ---

# %% [markdown]
# ## 3.1 METHODOLOGY

# %% [markdown]
# (c) Construction and execution the packages/methods/functions of Python codes for developing the regression model.

# %% [markdown]
# ### 3.1.1 Load Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import probplot
from sklearn.preprocessing import scale
from scipy.stats import shapiro
from scipy.stats import levene


df= pd.read_csv("Dataset_Loan_Bank.csv")

df.info()

df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 524 entries, 0 to 523
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            477 non-null    object
#  1   Gender             466 non-null    object
#  2   Married            474 non-null    object
#  3   Dependents         463 non-null    object
#  4   Education          478 non-null    object
#  5   Self_Employed      454 non-null    object
#  6   ApplicantIncome    477 non-null    float64
#  7   CoapplicantIncome  477 non-null    float64
#  8   CombinedIncome     477 non-null    float64
#  9   LoanAmount         461 non-null    float64
#  10  Loan_Amount_Term   468 non-null    float64
#  11  Credit_History     439 non-null    float64
#  12  Property_Area      477 non-null    object
#  13  Loan_Status        477 non-null    object
#  14  Loan_Default       331 non-null    object
# dtypes: float64(6), object(9)
# ...

# %%
df["Loan_Default"].unique()
# Out:
# array(['Y', nan, 'N'], dtype=object)

# %% [markdown]
# ---
#
# ### 3.1.2 Refine Data

# %%
df[df.isnull().any(axis=1)]
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 1    LP001003   Male     Yes          1  Graduate            No
# 2    LP001350   Male     Yes        NaN  Graduate            No
# 3    LP001356   Male     Yes          0  Graduate            No
# 4    LP001357   Male     NaN        NaN  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 519       NaN    NaN     NaN        NaN       NaN           NaN
# 520       NaN    NaN     NaN        NaN       NaN           NaN
# 521       NaN    NaN     NaN        NaN       NaN           NaN
# 522       NaN    NaN     NaN        NaN       NaN           NaN
# 523       NaN    NaN     NaN        NaN   #DIV/0!           NaN
#
#      ApplicantIncome  CoapplicantIncome  CombinedIncome  LoanAmount  \
# 0             5849.0                0.0          5849.0         NaN
# ...

# %%
applicant =df.dropna()

applicant
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 5    LP001580    Male     Yes          2      Graduate            No
# 6    LP002082    Male     Yes          0      Graduate           Yes
# 7    LP002820    Male     Yes          0      Graduate            No
# 8    LP002958    Male      No          0      Graduate            No
# 9    LP001758    Male     Yes          2      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 471  LP001699    Male      No          0      Graduate            No
# 472  LP001030    Male     Yes          2      Graduate            No
# 473  LP002314  Female      No          0  Not Graduate            No
# 474  LP002917  Female      No          0  Not Graduate            No
# 475  LP002300  Female      No          0  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  CombinedIncome  LoanAmount  \
# 5             8000.0                0.0          8000.0       200.0
# ...

# %%
applicant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, 5 to 475
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            260 non-null    object
#  1   Gender             260 non-null    object
#  2   Married            260 non-null    object
#  3   Dependents         260 non-null    object
#  4   Education          260 non-null    object
#  5   Self_Employed      260 non-null    object
#  6   ApplicantIncome    260 non-null    float64
#  7   CoapplicantIncome  260 non-null    float64
#  8   CombinedIncome     260 non-null    float64
#  9   LoanAmount         260 non-null    float64
#  10  Loan_Amount_Term   260 non-null    float64
#  11  Credit_History     260 non-null    float64
#  12  Property_Area      260 non-null    object
#  13  Loan_Status        260 non-null    object
#  14  Loan_Default       260 non-null    object
# dtypes: float64(6), object(9)
# memory usage: 32.5+ KB

# %% [markdown]
# ---
#
# ### 3.1.3 Create Sample Data from Applicant

# %%
random = applicant.sample(n=10, random_state=332)
print("Ten random samples of the dataset:\n")
random
# Out:
# Ten random samples of the dataset:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 222  LP001006    Male     Yes          0  Not Graduate            No
# 457  LP001560    Male     Yes          0  Not Graduate            No
# 28   LP001871  Female      No          0      Graduate            No
# 470  LP002690    Male      No          0      Graduate            No
# 239  LP002777    Male     Yes          0      Graduate            No
# 374  LP001245    Male     Yes          2  Not Graduate           Yes
# 318  LP001868    Male      No          0      Graduate            No
# 400  LP001248    Male      No          0      Graduate            No
# 213  LP001974  Female      No          0      Graduate            No
# 102  LP001750    Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  CombinedIncome  LoanAmount  \
# 222           2583.0             2358.0          4941.0       120.0
# ...

# %%
applicant.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome',
#        'CombinedIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History',
#        'Property_Area', 'Loan_Status', 'Loan_Default'],
#       dtype='object')

# %% [markdown]
# ---
#
# ### 3.1.4 Count for Each Features

# %%
#display all columns item value counts

gen=applicant['Gender'].value_counts()
print("\nGender:\n",gen)

mar=applicant['Married'].value_counts()
print("\n Marital Status:\n",mar)

dep=applicant['Dependents'].value_counts()
print("\nDependents:\n",dep)

edu=applicant['Education'].value_counts()
print("\n Education:\n",edu)

emp=applicant['Self_Employed'].value_counts()
print("\n Employment:\n",emp)

inc=applicant['ApplicantIncome'].value_counts()
print("\n Applicant Income:\n",inc)

coi=applicant['CoapplicantIncome'].value_counts()
print("\n Coapplicant Income:\n",coi)

com=applicant['CombinedIncome'].value_counts()
print("\n Combined Income:\n",com)

lot=applicant['LoanAmount'].value_counts()
print("\n Loan Amount:\n",lot)

lat=applicant['Loan_Amount_Term'].value_counts()
print("\n Loan Term:\n",lat)

ch=applicant['Credit_History'].value_counts()
print("\n Credit History:\n",ch)

pa=applicant['Property_Area'].value_counts()
print("\n Property Area:\n",pa)

ls=applicant['Loan_Status'].value_counts()
print("\n Loan Status:\n",ls)

ld=applicant['Loan_Default'].value_counts()
print("\n Loan Default:\n",ld)
# Out:
# Gender:
#  Gender
# Male      217
# Female     43
# Name: count, dtype: int64
#
#  Marital Status:
#  Married
# Yes    175
# No      85
# Name: count, dtype: int64
#
# Dependents:
#  Dependents
# 0     155
# 2      46
# 1      38
# 3+     21
# Name: count, dtype: int64
#
#  Education:
#  Education
# Graduate                        200
# Not Graduate                     57
# model = sm.OLS(y, X).fit()        1
# import statsmodels.api as sm      1
# import numpy as np                1
# Name: count, dtype: int64
#
#  Employment:
#  Self_Employed
# No     233
# Yes     27
# Name: count, dtype: int64
#
#  Applicant Income:
#  ApplicantIncome
# 2500.0    5
# 3500.0    3
# 6250.0    3
# 6000.0    3
# 4000.0    2
#          ..
# 5417.0    1
# 3748.0    1
# 3987.0    1
# 5391.0    1
# 1963.0    1
# Name: count, Length: 235, dtype: int64
#
#  Coapplicant Income:
#  CoapplicantIncome
# 0.0       105
# 2500.0      3
# 1666.0      3
# 1300.0      2
# 2083.0      2
#          ...
# ...

# %%
applicant['LoanAmount']
# Out:
# 5      200.0
# 6      184.0
# 7      211.0
# 8      172.0
# 9      210.0
#        ...
# 471     59.0
# 472     17.0
# 473     66.0
# 474     70.0
# 475     53.0
# Name: LoanAmount, Length: 260, dtype: float64

# %% [markdown]
# ---
#
# ### 3.1.5 Data Loan Default

# %%
default_no = applicant[applicant['Loan_Default'] == 'N']
default_no
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 5    LP001580    Male     Yes          2      Graduate            No
# 7    LP002820    Male     Yes          0      Graduate            No
# 10   LP002622    Male     Yes          2      Graduate            No
# 12   LP001811    Male     Yes          0  Not Graduate            No
# 17   LP002484    Male     Yes         3+      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 470  LP002690    Male      No          0      Graduate            No
# 472  LP001030    Male     Yes          2      Graduate            No
# 473  LP002314  Female      No          0  Not Graduate            No
# 474  LP002917  Female      No          0  Not Graduate            No
# 475  LP002300  Female      No          0  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  CombinedIncome  LoanAmount  \
# 5             8000.0                0.0          8000.0       200.0
# ...

# %%
default_yes = applicant[applicant['Loan_Default'] == 'Y']
default_yes
# Out:
#       Loan_ID  Gender Married Dependents                   Education  \
# 6    LP002082    Male     Yes          0                    Graduate
# 8    LP002958    Male      No          0                    Graduate
# 9    LP001758    Male     Yes          2                    Graduate
# 14   LP001713    Male     Yes          1                    Graduate
# 30   LP002234    Male      No          0                    Graduate
# 39   LP001238    Male     Yes         3+  model = sm.OLS(y, X).fit()
# 63   LP001491    Male     Yes          2                    Graduate
# 68   LP002706    Male     Yes          1                Not Graduate
# 75   LP002785    Male     Yes          1                    Graduate
# 77   LP002892    Male     Yes          2                    Graduate
# 103  LP001199    Male     Yes          2                Not Graduate
# 109  LP001882    Male     Yes         3+                    Graduate
# 112  LP002231  Female      No          0                    Graduate
# ...

# %%
default_yes[['LoanAmount','CombinedIncome']].describe()
# Out:
#        LoanAmount  CombinedIncome
# count   51.000000       51.000000
# mean   123.588235     5057.215686
# std     40.603042     1434.212081
# min     44.000000     2479.000000
# 25%    100.000000     3999.500000
# 50%    123.000000     4763.000000
# 75%    144.500000     5984.000000
# max    240.000000     7978.000000

# %%
default_no[['LoanAmount','CombinedIncome']].describe()
# Out:
#        LoanAmount  CombinedIncome
# count  209.000000      209.000000
# mean   117.421053     4939.999617
# std     40.687301     1403.118697
# min     17.000000     1963.000000
# 25%     96.000000     3812.000000
# 50%    118.000000     4843.000000
# 75%    140.000000     5935.000000
# max    255.000000     8000.000000

# %%
applicant.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  CombinedIncome  LoanAmount  \
# count       260.000000         260.000000      260.000000  260.000000
# mean       3736.123077        1226.868923     4962.992000  118.630769
# std        1431.594467        1222.971742     1407.247976   40.666482
# min         645.000000           0.000000     1963.000000   17.000000
# 25%        2675.750000           0.000000     3855.750000   96.750000
# 50%        3454.500000        1280.000000     4838.000000  120.000000
# 75%        4390.000000        2080.000000     5976.000000  140.000000
# max        8000.000000        4600.000000     8000.000000  255.000000
#
#        Loan_Amount_Term  Credit_History
# count        260.000000      260.000000
# mean         343.107692        0.980769
# std           61.228132        0.137600
# min           60.000000        0.000000
# 25%          360.000000        1.000000
# 50%          360.000000        1.000000
# 75%          360.000000        1.000000
# ...

# %%
default_yes.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  CombinedIncome  LoanAmount  \
# count        51.000000          51.000000       51.000000   51.000000
# mean       3908.000000        1149.215686     5057.215686  123.588235
# std        1481.978637        1177.476612     1434.212081   40.603042
# min        1820.000000           0.000000     2479.000000   44.000000
# 25%        2854.500000           0.000000     3999.500000  100.000000
# 50%        3333.000000        1040.000000     4763.000000  123.000000
# 75%        5044.500000        1850.000000     5984.000000  144.500000
# max        7787.000000        4301.000000     7978.000000  240.000000
#
#        Loan_Amount_Term  Credit_History
# count         51.000000       51.000000
# mean         344.000000        0.941176
# std           68.164507        0.237635
# min           60.000000        0.000000
# 25%          360.000000        1.000000
# 50%          360.000000        1.000000
# 75%          360.000000        1.000000
# ...

# %%
default_no.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  CombinedIncome  LoanAmount  \
# count       209.000000         209.000000      209.000000  209.000000
# mean       3694.181818        1245.817799     4939.999617  117.421053
# std        1419.512950        1235.824966     1403.118697   40.687301
# min         645.000000           0.000000     1963.000000   17.000000
# 25%        2620.000000           0.000000     3812.000000   96.000000
# 50%        3466.000000        1300.000000     4843.000000  118.000000
# 75%        4354.000000        2083.000000     5935.000000  140.000000
# max        8000.000000        4600.000000     8000.000000  255.000000
#
#        Loan_Amount_Term  Credit_History
# count        209.000000      209.000000
# mean         342.889952        0.990431
# std           59.589560        0.097588
# min           84.000000        0.000000
# 25%          360.000000        1.000000
# 50%          360.000000        1.000000
# 75%          360.000000        1.000000
# ...

# %% [markdown]
# ---
#
# ### 3.1.6 Shape

# %%
ns=default_no.shape
ys=default_yes.shape

print (ns,ys)
# Out:
# (209, 15) (51, 15)

# %% [markdown]
# ---
#
# ### 3.1.7 Create Sample Data from Loan Default

# %%
ld_n = default_no.sample(n=51, random_state=209)
print("Sample 51 observations from Loan Default (N):\n")
ld_n
# Out:
# Sample 51 observations from Loan Default (N):
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 231  LP001279    Male      No          0      Graduate            No
# 56   LP002659    Male     Yes         3+      Graduate            No
# 95   LP001439    Male     Yes          0  Not Graduate            No
# 321  LP001664    Male      No          0      Graduate            No
# 390  LP001325    Male      No          0  Not Graduate            No
# 391  LP002868    Male     Yes          2      Graduate            No
# 169  LP002964    Male     Yes          2  Not Graduate            No
# 5    LP001580    Male     Yes          2      Graduate            No
# 135  LP001744    Male      No          0      Graduate            No
# 389  LP001639  Female     Yes          0      Graduate            No
# 47   LP002175    Male     Yes          0      Graduate            No
# 238  LP001720    Male     Yes         3+  Not Graduate            No
# ...

# %%
ld_y = default_yes.sample(n=51, random_state=51)
print("Sample 51 observations from Loan Default (Y)):\n")
ld_y
# Out:
# Sample 51 observations from Loan Default (Y)):
#       Loan_ID  Gender Married Dependents                   Education  \
# 30   LP002234    Male      No          0                    Graduate
# 466  LP002370    Male      No          0                Not Graduate
# 140  LP001715    Male     Yes         3+                Not Graduate
# 112  LP002231  Female      No          0                    Graduate
# 6    LP002082    Male     Yes          0                    Graduate
# 469  LP002087  Female      No          0                    Graduate
# 305  LP002772    Male      No          0                    Graduate
# 129  LP002821    Male      No          0                Not Graduate
# 358  LP002455    Male     Yes          2                    Graduate
# 246  LP001841    Male      No          0                Not Graduate
# 399  LP002361    Male     Yes          0                    Graduate
# 9    LP001758    Male     Yes          2                    Graduate
# ...

# %% [markdown]
# ---
#
# ### 3.1.8 T-test

# %%
statistic, p_value = stats.ttest_ind(applicant['CombinedIncome'][applicant['Loan_Default'] == 'N'],
                applicant['CombinedIncome'][applicant['Loan_Default'] == 'Y'])


print(f"t's test statistic: {statistic}")
print(f"P-value: {p_value}")

alpha=0.05

if p_value > alpha:
    print("The means of the two groups are approximately equal.")
else:
    print("The means of the two groups are significantly different.")
# Out:
# t's test statistic: -0.5325822006573454
# P-value: 0.5947812103891803
# The means of the two groups are approximately equal.

# %% [markdown]
# ---
#
# ### 3.1.9 Visualization based on T-Test and Mean of The DataFrame

# %%
sns.boxplot(x="Loan_Default", y="CombinedIncome", hue="Loan_Default", showmeans=True,data=applicant)
plt.xlabel('Loan Default')
plt.ylabel('CombinedIncome')
plt.title('Boxplot of Combined Income based on Loan Default')
plt.show()

# %% [markdown]
# ---
#
# ### 3.1.10 Levene's test

# %%
stat, p_levene = levene(scale(ld_n['CombinedIncome']), scale(ld_y['CombinedIncome']))

print(f"Homogeneity of Variance Statistic: {stat, p_levene}")


alpha = 0.05  # Significance level

if p_levene > alpha:
    print("Sample looks like it came from a normal distribution (fail to reject H0)")
else:
    print("Sample does not look like it came from a normal distribution (reject H0)")
# Out:
# Homogeneity of Variance Statistic: (0.1325179295105228, 0.7166040738757871)
# Sample looks like it came from a normal distribution (fail to reject H0)

# %% [markdown]
# ---
#
# ### 3.1.11 Shapiro-Wilk test

# %%
stat1, p_value1 = shapiro(scale(ld_n['CombinedIncome']))
stat2, p_value2 = shapiro(scale(ld_y['CombinedIncome']))

print(f'Shapiro-Wilk test for Loan Default (N): Statistic={stat1}, p-value={p_value1}')

alpha = 0.05  # Significance level

if p_value1 > alpha:
    print("Sample looks like it came from a normal distribution (fail to reject H0)")
else:
    print("Sample does not look like it came from a normal distribution (reject H0)")


print(f'\nShapiro-Wilk test for Loan Default (Y): Statistic={stat2}, p-value={p_value2}')

alpha = 0.05  # Significance level

if p_value2 > alpha:
    print("Sample looks like it came from a normal distribution (fail to reject H0)")
else:
    print("Sample does not look like it came from a normal distribution (reject H0)")
# Out:
# Shapiro-Wilk test for Loan Default (N): Statistic=0.9676445126533508, p-value=0.17627598345279694
# Sample looks like it came from a normal distribution (fail to reject H0)
#
# Shapiro-Wilk test for Loan Default (Y): Statistic=0.969515323638916, p-value=0.21113626658916473
# Sample looks like it came from a normal distribution (fail to reject H0)

# %%
plt.subplot(1, 2, 1)
sns.histplot(ld_n['CombinedIncome'], kde=True, color='blue', label='Loan Default N')
plt.title('Histogram of Loan Default (Y)')
plt.xlabel('Combined Income')
plt.ylabel('Number of Applicant')

plt.subplot(1, 2, 2)
sns.histplot(ld_y['CombinedIncome'], kde=True, color='green', label='Loan Default Y')
plt.title('Histogram of Loan Default (N))')
plt.xlabel('Combined Income')
plt.ylabel('Number of Applicant')

plt.show()

# %% [markdown]
# ---
#
# ### 3.1.12 Normality

# %%
sns.histplot(ld_n['CombinedIncome'], kde=True, label='Loan Default Y')
sns.histplot(ld_y['CombinedIncome'], kde=True, label='Loan Default N')
plt.title('Distribution based on t-test')
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ### 3.1.13 Scatter plot and Correlation

# %%
g = sns.FacetGrid(applicant, hue="Loan_Default", height=6)

# Scatter plot
g.map(plt.scatter, "CombinedIncome", "LoanAmount")

# Adding legend
g.add_legend()

# Show the plot
plt.show()

# %%
sns.jointplot(x="CombinedIncome", y="LoanAmount", data=applicant)

# %%
ld_n.corr(numeric_only=True)
# Out:
#                    ApplicantIncome  CoapplicantIncome  CombinedIncome  \
# ApplicantIncome           1.000000          -0.387071        0.691216
# CoapplicantIncome        -0.387071           1.000000        0.398768
# CombinedIncome            0.691216           0.398768        1.000000
# LoanAmount                0.301672           0.322252        0.552599
# Loan_Amount_Term         -0.052432           0.038737       -0.021788
# Credit_History           -0.124396           0.151345       -0.005106
#
#                    LoanAmount  Loan_Amount_Term  Credit_History
# ApplicantIncome      0.301672         -0.052432       -0.124396
# CoapplicantIncome    0.322252          0.038737        0.151345
# CombinedIncome       0.552599         -0.021788       -0.005106
# LoanAmount           1.000000          0.126036       -0.058534
# Loan_Amount_Term     0.126036          1.000000       -0.030001
# Credit_History      -0.058534         -0.030001        1.000000

# %%
ld_y.corr(numeric_only=True)
# Out:
#                    ApplicantIncome  CoapplicantIncome  CombinedIncome  \
# ApplicantIncome           1.000000          -0.437178        0.674385
# CoapplicantIncome        -0.437178           1.000000        0.369254
# CombinedIncome            0.674385           0.369254        1.000000
# LoanAmount                0.553719           0.248063        0.775819
# Loan_Amount_Term         -0.149697           0.225993        0.030855
# Credit_History           -0.159979           0.014771       -0.153181
#
#                    LoanAmount  Loan_Amount_Term  Credit_History
# ApplicantIncome      0.553719         -0.149697       -0.159979
# CoapplicantIncome    0.248063          0.225993        0.014771
# CombinedIncome       0.775819          0.030855       -0.153181
# LoanAmount           1.000000          0.127384       -0.240934
# Loan_Amount_Term     0.127384          1.000000       -0.059265
# Credit_History      -0.240934         -0.059265        1.000000

# %%
#Calculate correlation for applicant dataset
correlation_ld_n = ld_n['LoanAmount'].corr(ld_n['CombinedIncome'])
print(f'Correlation between Loan Amount and Combined Income(Loan Default N): {correlation_ld_n}')

# Calculate correlation for with_post dataset
correlation_ld_y = ld_y['LoanAmount'].corr(ld_y['CombinedIncome'])
print(f'\nCorrelation between Loan Amount and Combined Income(Loan Default Y): {correlation_ld_y}')
# Out:
# Correlation between Loan Amount and Combined Income(Loan Default N): 0.5525993911055755
#
# Correlation between Loan Amount and Combined Income(Loan Default Y): 0.7758188724354704

# %% [markdown]
# ---
#
# ### 3.1.14 Linear Regression on Loan Default N

# %%
X = sm.add_constant(ld_n['CombinedIncome'])
y = ld_n['LoanAmount']

model = sm.OLS(y, X).fit()
print(model.summary())

# Plotting the data and regression line
plt.scatter(X['CombinedIncome'], y)
plt.plot(X['CombinedIncome'], model.predict(X), color='black', linewidth=3)
plt.xlabel('Combined Income')
plt.ylabel('Loan Amount')
plt.title('Linear Regression with Statsmodels')
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             LoanAmount   R-squared:                       0.305
# Model:                            OLS   Adj. R-squared:                  0.291
# Method:                 Least Squares   F-statistic:                     21.54
# Date:                Fri, 26 Jan 2024   Prob (F-statistic):           2.62e-05
# Time:                        10:20:21   Log-Likelihood:                -250.94
# No. Observations:                  51   AIC:                             505.9
# Df Residuals:                      49   BIC:                             509.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             39.3257     16.675      2.358      0.022       5.815      72.836
# ...

# %% [markdown]
# ---
#
# ### 3.1.15 Linear Regression on Loan Default Y

# %%
X = sm.add_constant(ld_y['CombinedIncome'])
y = ld_y['LoanAmount']

model = sm.OLS(y, X).fit()
print(model.summary())

# Plotting the data and regression line
plt.scatter(X['CombinedIncome'], y)
plt.plot(X['CombinedIncome'], model.predict(X), color='black', linewidth=3)
plt.xlabel('Combined Income')
plt.ylabel('Loan Amount')
plt.title('Linear Regression with Statsmodels')
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             LoanAmount   R-squared:                       0.602
# Model:                            OLS   Adj. R-squared:                  0.594
# Method:                 Least Squares   F-statistic:                     74.08
# Date:                Fri, 26 Jan 2024   Prob (F-statistic):           2.29e-11
# Time:                        10:20:22   Log-Likelihood:                -237.27
# No. Observations:                  51   AIC:                             478.5
# Df Residuals:                      49   BIC:                             482.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             12.5131     13.404      0.934      0.355     -14.424      39.450
# ...

# %% [markdown]
# ---
#
# ## 3.2 RESULTS

# %% [markdown]
# (d) Display the results and discussion with detailed visualization.

# %% [markdown]
# ### 3.2.1 DISCUSSION

# %% [markdown]
# In this project, the dataset originally consisted of 524 entries. The dataset excludes missing values, resulting in a refined dataset containing 260 entries. The refined dataset is specifically used to observe the relationship between dependent and independent variables for this project. Analyzing the behavior of 10 randomly selected data points from the dataset provides insights into the general trends or patterns present. The display of value counts, focusing on "LoanAmount," "CombinedIncome," and "Loan_Default," provides an overview of the frequency distribution of unique values within the dataset. The highest value count for "Loan Amount" is 10 which is RM100000 while the lowest value count is 1 which is RM53000. Similarly, in the case of "Combined Income," the highest value count is 3 with an income of RM3750 and RM6000. In contrast, the lowest value count is 1  which is RM1963 as the lowest combined income. The categorical variable "Loan_Default" exhibits two distinct counts, with 'Yes' having a count of 51 and 'No' having a count of 209.
#
# For the analysis, loan defaults are separated into two categories: 'Yes' and 'No'. A statistical summary of "Combined Income" and "LoanAmount" is provided for each loan default category to offer insights into the distribution and characteristics of the data.
#
# Statistical Summary for Loan Default: Yes
# <center>
# <img src="Image/Loan Default Yes.jpg" alt="Loan_Default: Yes" width="250" height="250"/>
# </center>
#
# Statistical Summary for Loan Default: No
# <center>
# <img src="Image/Loan Default No.jpg" alt="Loan_Default: No" width="250" height="250"/>
# </center>
#
#
# The t-test is employed to evaluate the differences or significance between "CombinedIncome" and "Loan_Default". The objectives of the t-test are to compare the means of the two groups. The test statistic is -0.5326 and the p-value associated with the t-test is 0.5948. Since The p-value is greater than  0.05, there is insufficient evidence to reject the null hypothesis. Therefore, the hypothesis that the means of the two groups are equal is failed to rejected. Based on the results of the t-test, it can be concluded that no statistically significant difference exists between the means of the two groups. This suggests that, at the chosen level of significance, the evidence does not support the assertion that the means are different. After conducting the statistical analysis, a visualization of the mean was conducted using a boxplot. The box plot displays several key components, including the median, which is the line within the box, the Interquartile Range (IQR) represented by the box, and the whiskers extending from the box. Below, the box plot representation provides a visual that includes several key components discussed earlier.
#
# <center>
# <img src="Image/boxplot.png" alt="Box plot": No" width="500" height="500"/>
# </center>

# %% [markdown]
# Levene's test and Shapiro-Wilk test are statistical methods utilized to assess the assumptions of the t-tests. Levene's test assesses the homogeneity of variances assumption, which states that the variances of the populations being compared are equal meanwhile the Shapiro-Wilk test assesses the normality assumption, which states that the data within each group or sample is drawn from a normally distributed population. Levene's test helps verify the assumption of homogeneity of variances, while the Shapiro-Wilk test helps verify the assumption of normality. The Homogeneity of variance statistic obtained from Levene's test is (0.1325179295105228, 0.7166040738757835) where the test statistic is 0.132517929510522 and the p-value associated with the test is 0.7166040738757835. The p-value of 0.7166 is greater than 0.05 which suggests that the assumption of homogeneity of variances is met, and the parametric tests (t-test) can be used with confidence. The Shapiro-Wilk test results for Loan Default (N) yield a statistic of 0.96764451265335086 with a p-value of 0.17627598345279694. The p-value is greater than 0.05, hence the null hypothesis cannot be rejected. Similarly, for Loan Default (Y), the statistic is 0.9695153236389165 with a p-value of 0.211136266589164731. Once more, the p-value is greater than 0.05, leading to the same conclusion that the null hypothesis cannot be rejected. Based on the Shapiro-Wilk test, the samples exhibit characteristics of a normal distribution, as evidenced by the failure to reject the null hypothesis. The Shapiro-Wilk test results for both groups indicate that the assumption of normality is met. This allows for the implementation of a normality histogram.
# The plot illustrates the distribution of data, showcasing characteristics consistent with a normal distribution.
#
# <center>
# <img src="Image/Histogram.png" alt=Histogram" width="500" height="500"/>
# </center>

# %% [markdown]
# Correlation analysis helps identify patterns and associations between variables in datasets. The correlation coefficient ranges from -1 to 1 where 1 indicates a perfect positive correlation (as one variable increases, the other also increases), -1 indicates a perfect negative correlation (as one variable increases, the other decreases) and 0 indicates no correlation between the variables. For "Loan Default N", the correlation coefficient between "Loan Amount" and "Combined Income" is 0.5526. This indicates a moderate positive correlation between the two variables. Meanwhile, the correlation coefficient between "Loan Amount" and "Combined Income" for "Loan Default Y" is 0.7758. This indicates a strong positive correlation between the two variables. In both cases, the positive correlation suggests that as "Combined Income" increases, the "Loan Amount" also tends to increase. However, the strength of this relationship is stronger for the "Loan Default Y" group compared to the "Loan Default N" group.
# <center>
# <img src="Image/scatter plot.jpg" alt=Scatter Plot" width="500" height="500"/>
# </center>
#
# The scatter plot shows the relationship between "CombinedIncome" and "LoanAmount" with "CombinedIncome" on the x-axis and "LoanAmount" on the y-axis.This scatter plot shows a positive correlation, indicating that as the "CombinedIncome" (x-variable) increases, the "LoanAmount" (y-variable) increases as well. The "hue" parameter introduces an additional categorical variable into the plot where the "hue" represents the "Loan_Default". The absence of outliers in the dataset suggests a consistent and uniform pattern, reinforcing the strength of the positive correlation observed between the two variables. Examining the scatter plot with the color-coded information of "Loan_Default" where blue for 'No' and Orange for Ýes' allows for a detailed understanding of how the relationship between "Combined Income" and "Loan Amount" may differ based on loan default status. A joint plot combines a scatter plot of the two variables with a histogram.

# %% [markdown]
# ---
#
# ### 3.2.2 INTERPRETATION ON OLS REGRESSION TABLE

# %% [markdown]
# <center>
# <img src="Image/Loan_Default_No.jpeg" alt="Summary No" width="500" height="500"/>
# </center>
#
# The most significant metric that this summary OLS Regression results generate is R-squared. R-squared is the assessment of how much of the independent variable ("CombinedIncome" of "LoanDefault No") is explained by changes in our dependent variables. With a percentage of 0.602, our model accounts for 60.2% of the variation in our "LoanAmount" variable which indicates a moderate level of goodness of fit. Our adjusted R-Squares, 0.594 slightly lower than the R-Squared value itself which illustrates how adding additional variable is penalised. The obtained F-Statistic is 74.08 and Probability (Prob F-Statistic) is 2.29e-11 which quites low. According to the very low p-vaue of "CombinedIncome" (0.000), the F-statistic of 70.48 considered high in the sense that the evidence against the null hypothesis is strong. This inferred that the model is statistically significant. Because the p-values for each coefficient test the null hypothesis that the corresponding coefficient is equal to zero, the low p-value for "CombinedIncome" (0.000) in this instance indicates that it is a significant predictor. The coefficients of both constant(intercept) and "CombinedIncome" are 12.5131 and 0.0220. These are the coefficients for the regression equation which in this model, the regression equation is LoanAmount = 12.5131 + 0.0220*CombinedIncome.The 95% confidence interval for the variable CombinedIncome in this instance is [0.017, 0.027]. The summary table also shows the diagnostic statistics that provide insights into various aspects of the regression model and its residuals. The residuals' normality is evaluated using the Omnibus test. A test statistic of 3.440 indicates a deviation from normalcy, a low p-value (usually less than 0.05) would suggest that the residuals deviate considerably from a normal distribution. The Jarque Bera test also assessed for the normalcy residual which in our case the obtained value is 2.783 with given low p-value suggest that a deviation from the norm.
#
#
# <center>
# <img src="Image/Loan_Default_Noi.jpeg" alt="Graph No" width="500" height="500"/>
# </center>
#
# According to the figure above, the black line represents the least squares regression line for this dataset. The blue dots represent the actual data points from the sample data of LoanAmount and CombinedIncome.
#
#
# <center>
# <img src="Image/Loan_Default_Yes.jpeg" alt="Summary Yes" width="500" height="500"/>
# </center>
#
# With an R-squared of 0.305, the linear connection between the independent variable ("CombinedIncome") and the "LoanAmount" when "loanDefault No" accounts for around 30.5% of the variability in "LoanAmount". The model is unable to explain 69.5% of the variability that remains. The model's adjusted R-squared, which takes the number of predictors into account, is 0.291. Compared to the R-squared value, it is somewhat less.The model is statistically significant since the F-statistic is 21.54 and the related probability, Prob (F-statistic), is extremely low, at about 2.26e-05. 39.3257 is the intercept, or constant. This is the approximate "LoanAmount" when the "CombinedIncome" is equal to 0. The constant's p-value of 0.022 indicates that the intercept differs from zero in a meaningful way Besides, the CombinedIncome's coefficient is 0.0153. This shows how much the "LoanAmount" would change, on average, if the "CombinedIncome" increased by one unit. CombinedIncome's p-value is extremely low (0.000), suggesting that it is a statistically significant predictor. Meanwhile, the diagnostic statistic that the Durbin-Watson obtained is 1.903 which less than 2, which suggests that some positives autocorrelation in the residuals.
#
#
# <center>
# <img src="Image/Loan_Default_Yesii.jpeg" alt="Summary Yes" width="500" height="500"/>
# </center>
#
# According the figure above, the black line represents the least squares regression line for this dataset. The blue dots represent the actual data points from the sample data of LoanAmount and CombinedIncome.

# %% [markdown]
# ---
#
# ## 3.3 CONCLUSION

# %% [markdown]
# (e) Conclusion of the project which may lead to an informed decision by administrators.

# %% [markdown]
# In conclusion, our project provides valuable insights into the relationship between the "Loan Amount" as the dependent variable and "Combined Income" and "Loan Default" as independent variables in the context of banking and lending practices using linear regression analysis. This knowledge is crucial for implementing strategies to optimize lending practices, mitigate risk, and improve decision-making processes within the financial sector.
#
# Firstly, the application of the parametric t-test could only be used upon meeting presumptions satisfied. Levene's test was employed to assess the homogeneity of variances across groups, ensuring the validity of comparisons made. Furthermore, the Shapiro-Wilk test was utilized to evaluate the normality assumption within the data distributions. The obtained Homogeneity of Variance statistic from Levene's test and its associated p-value indicates that the assumption of homogeneity of variances is met. Due to this, parametric tests such as the t-test can be used to compare the means of the two groups. Furthermore, the Shapiro-Wilk test results and corresponding p-values for both groups demonstrate that the null hypothesis of normality cannot be rejected. This suggests that the samples exhibit characteristics consistent with a normal distribution, further validating the reliability of the statistical analyses conducted.
#
# According to our project, there is a significant positive correlation between "CombinedIncome" and "LoanAmount", indicating that individuals with higher "CombinedIncome" tend to secure larger loans from financial institutions. Furthermore, the correlation coefficients for Loan_Default underscore the significance of income levels in loan repayment behavior. Specifically, observation for a stronger positive correlation between  CombineIncome and LoanAmount among borrowers with "Loan_Default" Yes on their loans compared to those with "Loan_Default" No. These findings highlight that combined income plays a critical role in determining both the amount of loan individuals secure and their ability to repay it, highlighting the necessity of income assessment in lending decisions.
#
# The results of our linear regression models demonstrate a moderate goodness fit model of approximately 60.2% for the dependent variable of LoanAmount when the dataset is predicted based on the "CombinedIncome" with "Loan_Default" 'No'. Similar to when "CombinedIncome" for "LoanDefault" is Yes, the R-Square shows a moderate level of goodness fit model, even though the value obtained is 30.5%. This is because 30.5% can be seen as rather good in some situations, such as the social sciences or finance, where human behavior is highly complicated and impacted by various factors. The R-squared value suggests that the "CombinedIncome" with LoanDefault Yes is a significant predictor of LoanAmount, but there are other factors at play as well.
#
# The project emphasizes the need for ongoing research to explore additional factors influencing the linear regression of the LoanAmount including, "Credit_History", "Self_Employed" "Dependents", "Married", or "Education". A deeper understanding of these factors could pave the way for more effective and efficient approaches to analyzing the "LoanAmount" variable, thereby enhancing the accuracy of predictive models and decision-making processes within the lending industry. Additionally, exploring the interplay between these factors and their impact on loan approval rates, default probabilities, and borrower profiles could offer valuable insights for financial institutions seeking to optimize lending practices and mitigate risk. As such, continued research in this area holds immense potential for advancing the field of financial analysis and facilitating more informed lending strategies in an increasingly complex economic landscape.

# %% [markdown]
# ---
#
# # 4. REFERENCES
#
# ---

# %% [markdown]
# 1. Ajaymanwani (2019) Loan approval prediction, Kaggle. Available at: https://www.kaggle.com/code/ajaymanwani/loan-approval-prediction/notebook
# 2. McCullum, N. (no date) Linear regression in python - a step-by-step guide, Nick McCullum Headshot. Available at: https://www.nickmccullum.com/python-machine-learning/linear-regression-python/
# 3. Jin Yun, L., & Kamisan, N. A. B. (2023). Multiple linear regression on personal loan applications and approvals. https://science.utm.my/procscimath/wp-content/uploads/sites/605/2023/10/156-168-Lee-Jin-Yun_Nur-Arina-Bazilah-Kamisan.pdf
# 4. Parajuli, P. (2020). Interpretation of Linear Regression . https://towardsdatascience.com/interpretation-of-linear-regression-dba45306e525
# 5. Khan Academy. (n.d.). Scatterplots and Correlation Review (article). Khan Academy. https://www.khanacademy.org/math/statistics-probability/describing-relationships-quantitative-data/introduction-to-scatterplots/a/scatterplots-and-correlation-review
# 6. Kendra Cherry, Mse. (2023, November 30). The role of correlations in psychology research. What is correlation? https://www.verywellmind.com/what-is-correlation-2794986
